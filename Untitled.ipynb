# %% [markdown]
# # Load Necessary Packages

# %%
import geopandas
import

# %% [markdown]
# # Load NECESSARY DATA

# %%
wa_puma = geopandas.read_file("data/raw/tl_2017_53_puma10.shp") 
wa_puma
# Out:
#    STATEFP10 PUMACE10  GEOID10  \
# 0         53    10200  5310200
# 1         53    10100  5310100
# 2         53    10400  5310400
# 3         53    10504  5310504
# 4         53    10503  5310503
# 5         53    10600  5310600
# 6         53    10703  5310703
# 7         53    11000  5311000
# 8         53    11502  5311502
# 9         53    11612  5311612
# 10        53    11701  5311701
# 11        53    11702  5311702
# 12        53    11703  5311703
# 13        53    11705  5311705
# 14        53    11103  5311103
# 15        53    11101  5311101
# 16        53    11104  5311104
# 17        53    11200  5311200
# 18        53    11300  5311300
# 19        53    11900  5311900
# 20        53    10300  5310300
# 21        53    10502  5310502
# 22        53    10701  5310701
# 23        53    10702  5310702
# 24        53    10902  5310902
# 25        53    11102  5311102
# 26        53    11801  5311801
# 27        53    11706  5311706
# 28        53    10800  5310800
# ...

# %% [markdown]
# # PLOT THE SPATIAL DATA FRAM AS A MAP

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(1,1, figsize = (10,8))
wa_puma.plot()
plt.show()
