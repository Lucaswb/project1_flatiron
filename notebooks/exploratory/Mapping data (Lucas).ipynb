# %% [markdown]
# # Creating visual maps of both King County and South King County

# %% [markdown]
# ### Goals for this notebook:
# - to load all the mapping data into geopandas from an shp file.
# - to filter out the puma's located within South King County and within all of King County.
# - to map these puma's such that a non-washington residents can understand where these pumas are located in relation to the rest of King County and the rest of Washington State
#
# *puma stands for public use microdata area's*

# %% [markdown]
# ## Our Method:

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import geopandas as gpd
import pysal as ps
# from pysal.contrib.viz import mapping as maps
# %matplotlib inline
# Out:
# /Users/lucasblasdel/opt/anaconda3/envs/oy-env/lib/python3.7/site-packages/pysal/explore/segregation/network/network.py:16: UserWarning: You need pandana and urbanaccess to work with segregation's network module
# You can install them with  `pip install urbanaccess pandana` or `conda install -c udst pandana urbanaccess`
#   "You need pandana and urbanaccess to work with segregation's network module\n"
# /Users/lucasblasdel/opt/anaconda3/envs/oy-env/lib/python3.7/site-packages/pysal/model/spvcm/abstracts.py:10: UserWarning: The `dill` module is required to use the sqlite backend fully.
#   from .sqlite import head_to_sql, start_sql

# %% [markdown]
# ## Loading Data
#
# We began by upploading the shp file containing all the puma's within Washington State and just gather specific info for each one of the columns. Since the PUMACE10 is the identifier for a given puma, it was of paticular importance to note that the value was being stored as an object and not an interger

# %%
wa_df = gpd.read_file("data/raw/tl_2017_53_puma10.shp")
wa_df.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 56 entries, 0 to 55
# Data columns (total 11 columns):
# STATEFP10     56 non-null object
# PUMACE10      56 non-null object
# GEOID10       56 non-null object
# NAMELSAD10    56 non-null object
# MTFCC10       56 non-null object
# FUNCSTAT10    56 non-null object
# ALAND10       56 non-null int64
# AWATER10      56 non-null int64
# INTPTLAT10    56 non-null object
# INTPTLON10    56 non-null object
# geometry      56 non-null object
# dtypes: int64(2), object(9)
# memory usage: 4.9+ KB

# %% [markdown]
# ## Cleanind Data

# %% [markdown]
# the filtering function below was used to assign color values based on where the puma is located. If the puma is located in South King county specifically, the function will assign it the value red, if located in king county but not south king county, then the function assigns green. Else the function assigns the color white.

# %%
def filtering_func(x):
    #this will be used to filter the puma values to get a simple yes or no value for the corresponding districts.
    filter_list1 = list(range(11610, 11616))
    filter_list2 = list(range(11601, 11610))
    filter_list2.append(11616)
    if any(x == filtered_num for filtered_num in filter_list1):
        return 'red'
    elif any(x == filtered_num for filtered_num in filter_list2):
        return 'green'
    else:
        return 'white'

# %% [markdown]
# Here we cleaned the data by switching the puma values from strings to intergers and then applied the filtering function to create a new column with each puma's corresponding color. We also sorted the table pumas.

# %%
wa_df['PUMACE10'] = wa_df['PUMACE10'].astype(int)
wa_df['color'] = wa_df['PUMACE10'].map(filtering_func)
wa_df.sort_values(by = ['PUMACE10'])
# Out:
#    STATEFP10  PUMACE10  GEOID10  \
# 1         53     10100  5310100
# 0         53     10200  5310200
# 20        53     10300  5310300
# 2         53     10400  5310400
# 55        53     10501  5310501
# 21        53     10502  5310502
# 4         53     10503  5310503
# 3         53     10504  5310504
# 5         53     10600  5310600
# 22        53     10701  5310701
# 23        53     10702  5310702
# 6         53     10703  5310703
# 28        53     10800  5310800
# 29        53     10901  5310901
# 24        53     10902  5310902
# 7         53     11000  5311000
# 15        53     11101  5311101
# 25        53     11102  5311102
# 14        53     11103  5311103
# 16        53     11104  5311104
# 17        53     11200  5311200
# 18        53     11300  5311300
# 47        53     11401  5311401
# 30        53     11402  5311402
# 43        53     11501  5311501
# 8         53     11502  5311502
# 48        53     11503  5311503
# 54        53     11504  5311504
# 34        53     11505  5311505
# 46        53     11506  5311506
# 33        53     11507  5311507
# 38        53     11601  5311601
# 50        53     11602  5311602
# 37        53     11603  5311603
# 49        53     11604  5311604
# 36        53     11605  5311605
# 39        53     11606  5311606
# 51        53     11607  5311607
# 53        53     11608  5311608
# 45        53     11609  5311609
# 52        53     11610  5311610
# 35        53     11611  5311611
# 9         53     11612  5311612
# 44        53     11613  5311613
# 42        53     11614  5311614
# 41        53     11615  5311615
# 32        53     11616  5311616
# 10        53     11701  5311701
# 11        53     11702  5311702
# 12        53     11703  5311703
# 40        53     11704  5311704
# 13        53     11705  5311705
# 27        53     11706  5311706
# 26        53     11801  5311801
# 31        53     11802  5311802
# 19        53     11900  5311900
#
#                                            NAMELSAD10 MTFCC10 FUNCSTAT10  \
# 1                Whatcom County--Bellingham City PUMA   G6120          S
# 0             Skagit, Island & San Juan Counties PUMA   G6120          S
# 20                     Chelan & Douglas Counties PUMA   G6120          S
# 2   Stevens, Okanogan, Pend Oreille & Ferry Counti...   G6120          S
# 55  Spokane County (North Central)--Spokane City (...   G6120          S
# 21  Spokane County (South Central)--Spokane City (...   G6120          S
# 4   Spokane County (East Central)--Greater Spokane...   G6120          S
# 3            Spokane County (Outer)--Cheney City PUMA   G6120          S
# 5   Whitman, Asotin, Adams, Lincoln, Columbia & Ga...   G6120          S
# 22  Benton & Franklin Counties--Pasco, Richland (N...   G6120          S
# 23  Benton County (East Central)--Kennewick & Rich...   G6120          S
# 6   Walla Walla, Benton (Outer) & Franklin (Outer)...   G6120          S
# 28                     Grant & Kittitas Counties PUMA   G6120          S
# 29  Yakima County (Central)--Greater Yakima City PUMA   G6120          S
# 24  Yakima County (Outer)--Sunnyside & Grandview C...   G6120          S
# 7           Lewis, Klickitat & Skamania Counties PUMA   G6120          S
# 15  Clark County (Southwest)--Vancouver City (West...   G6120          S
# 25  Clark County (West Central)--Salmon Creek & Ha...   G6120          S
# 14  Clark County (Southeast)--Vancouver (East), Ca...   G6120          S
# 16  Clark County (North)--Battle Ground City & Orc...   G6120          S
# 17         Cowlitz, Pacific & Wahkiakum Counties PUMA   G6120          S
# 18                 Grays Harbor & Mason Counties PUMA   G6120          S
# 47  Thurston County (Central)--Olympia, Lacey & Tu...   G6120          S
# 30                       Thurston County (Outer) PUMA   G6120          S
# 43  Pierce County (Central)--Tacoma City (Central)...   G6120          S
# 8   Pierce County (Northwest)--Peninsula Region & ...   G6120          S
# 48  Pierce County (West Central)--Lakewood City & ...   G6120          S
# 54  Pierce County (South Central)--Tacoma City (So...   G6120          S
# 34  Pierce County (North Central)--Tacoma (Port) &...   G6120          S
# 46  Pierce County (East Central)--Puyallup City & ...   G6120          S
# 33  Pierce County (Southeast)--Graham, Elk Plain &...   G6120          S
# 38                      Seattle City (Northwest) PUMA   G6120          S
# 50                      Seattle City (Northeast) PUMA   G6120          S
# 37  Seattle City (Downtown)--Queen Anne & Magnolia...   G6120          S
# 49        Seattle City (Southeast)--Capitol Hill PUMA   G6120          S
# 36   Seattle City (West)--Duwamish & Beacon Hill PUMA   G6120          S
# 39  King County (Northwest)--Shoreline, Kenmore & ...   G6120          S
# 51  King County (Northwest)--Redmond, Kirkland Cit...   G6120          S
# 53  King County (Northwest Central)--Greater Belle...   G6120          S
# 45  King County (Central)--Sammamish, Issaquah, Me...   G6120          S
# 52  King County (Central)--Renton City, Fairwood, ...   G6120          S
# 35  King County (West Central)--Burien, SeaTac, Tu...   G6120          S
# 9   King County (Far Southwest)--Federal Way, Des ...   G6120          S
# 44    King County (Southwest Central)--Kent City PUMA   G6120          S
# 42  King County (Southwest)--Auburn City & Lakelan...   G6120          S
# 41  King County (Southeast)--Maple Valley, Covingt...   G6120          S
# 32  King County (Northeast)--Snoqualmie City, Cott...   G6120          S
# 10  Snohomish County (Southwest)--Edmonds, Lynnwoo...   G6120          S
# 11  Snohomish County (West Central)--Mukilteo & Ev...   G6120          S
# 12  Snohomish County (Central)--Everett City (Cent...   G6120          S
# 40  Snohomish County (South Central)--Bothell (Nor...   G6120          S
# 13  Snohomish County (Central & Southeast)--Lake S...   G6120          S
# 27  Snohomish County (North)--Marysville & Arlingt...   G6120          S
# 26  Kitsap County (North)--Bainbridge Island City ...   G6120          S
# 31  Kitsap County (South)--Bremerton & Port Orchar...   G6120          S
# 19                  Clallam & Jefferson Counties PUMA   G6120          S
#
#         ALAND10    AWATER10   INTPTLAT10    INTPTLON10  \
# 1    5459332804  1028183246  +48.8426531  -121.8364325
# 0    5470622131  2441658886  +48.4470835  -122.1737477
# 20  12277996273   266195542  +47.8211284  -120.2675436
# 2   29389124389   489162432  +48.5031090  -118.7866777
# 55    107035463      820891  +47.7271030  -117.4260920
# 21    207096547     1798771  +47.6373660  -117.4451805
# 4     270926976     5004332  +47.6561281  -117.1818649
# 3    3983412021    35812133  +47.5972847  -117.1210417
# 5   22300152581   179320877  +46.9464148  -118.0223129
# 22    239800590    18718739  +46.2738284  -119.1002333
# 23    266682332    22871521  +46.1708950  -119.1429388
# 6   10401922840   248495777  +46.3118847  -119.0424324
# 28  12889632263   382410462  +47.1763426  -120.0122373
# 29    168577491     2344976  +46.6016947  -120.5495957
# 24  10956434067    38821657  +46.4565581  -120.7401446
# 7   15362252097   245302530  +46.2873462  -121.7656479
# 15    105510118    25158109  +45.6576149  -122.6599638
# 25     96150152      421727  +45.7002100  -122.6390656
# 14    194562348    17933409  +45.6090104  -122.3945141
# 16   1232299601    26859850  +45.8203890  -122.4500659
# 17   6049888066   889645985  +46.3738880  -123.2695118
# 18   7409888357  1072312003  +47.2161068  -123.6243566
# 47    204854981    16035406  +47.0289873  -122.8349812
# 30   1665604553   117808588  +46.9165765  -122.8284853
# 43     64705067     9514730  +47.2420687  -122.4658175
# 8     350604568   243415998  +47.2822884  -122.6738855
# 48    377070617    37329440  +47.0894734  -122.5523993
# 54    113288919     1249212  +47.1343759  -122.4122750
# 34    213119385    26853254  +47.2320641  -122.2738310
# 46    122864597      583552  +47.1370277  -122.2980971
# 33   3079677610    36519909  +46.9580085  -121.9390787
# 38     43437175     5995523  +47.6909932  -122.3619886
# 50     39486895    13834057  +47.6857542  -122.2858124
# 37     29279826     8323991  +47.6391415  -122.3720415
# 49     34295850    20392827  +47.5815050  -122.2745821
# 36     70104140    10124676  +47.5521279  -122.3523950
# 39     75073924     5794567  +47.7564420  -122.2787890
# 51     93365944    12948247  +47.6827310  -122.1668045
# 53     91442359    24875257  +47.6041090  -122.1675781
# 45    203445872    28674310  +47.5610064  -122.0701617
# 52     75931302     4694856  +47.4836108  -122.1904418
# 35    104685305     6835973  +47.4500687  -122.3101564
# 9     160638807   279665546  +47.4764651  -122.4271168
# 44     96646675     1914377  +47.3879703  -122.2127275
# 42    177945706     2750138  +47.2844346  -122.1690701
# 41   1704963276    21281417  +47.2986756  -121.7866429
# 32   2477645989    49838932  +47.5779171  -121.6433869
# 10     68399515     4144245  +47.8084278  -122.3246199
# 11     83423264     5930151  +47.8850557  -122.2739659
# 12     70550418     8829991  +47.9448287  -122.2116535
# 40    167183010      423762  +47.8165691  -122.1351261
# 13   2426932031    35309581  +47.9115286  -121.6064173
# 27   2587654967   228227352  +48.1798643  -121.7653478
# 26    471788534   383914048  +47.7295329  -122.6008257
# 31    551380708    58275888  +47.5116810  -122.7140668
# 19   9174879351  3408714183  +48.0037907  -123.8232377
#
#                                              geometry  color
# 1   POLYGON ((-122.406419 49.002305, -122.406168 4...  white
# 0   POLYGON ((-122.444216 48.645267, -122.436849 4...  white
# 20  POLYGON ((-120.235759 47.262147, -120.237732 4...  white
# 2   POLYGON ((-118.148586 47.886668, -118.148986 4...  white
# 55  POLYGON ((-117.411171 47.686226, -117.412237 4...  white
# 21  POLYGON ((-117.36373 47.678297, -117.362422 47...  white
# 4   POLYGON ((-117.155338 47.699711, -117.155092 4...  white
# 3   POLYGON ((-117.105276 47.610178, -117.105266 4...  white
# 5   POLYGON ((-117.382675 45.998039, -117.385431 4...  white
# 22  POLYGON ((-119.104272 46.277891, -119.104545 4...  white
# 23  POLYGON ((-119.052882 46.198173, -119.049918 4...  white
# 6   POLYGON ((-118.341664 46.737253, -118.339247 4...  white
# 28  POLYGON ((-119.305753 47.670388, -119.298843 4...  white
# 29  POLYGON ((-120.502178 46.548542, -120.502258 4...  white
# 24  POLYGON ((-120.128494 46.736192, -120.08493 46...  white
# 7   POLYGON ((-122.141671 46.754098, -122.141649 4...  white
# 15  POLYGON ((-122.618573 45.608619, -122.634962 4...  white
# 25  POLYGON ((-122.599417 45.722309, -122.599239 4...  white
# 14  POLYGON ((-122.454824 45.567844, -122.455166 4...  white
# 16  POLYGON ((-122.407333 45.639853, -122.407852 4...  white
# 17  POLYGON ((-122.935452 46.095123, -122.937388 4...  white
# 18  POLYGON ((-122.83186 47.521031, -122.831712 47...  white
# 47  POLYGON ((-122.820127 47.07024, -122.820003 47...  white
# 30  POLYGON ((-122.790154 47.170078, -122.78993 47...  white
# 43  POLYGON ((-122.437727 47.268046, -122.438331 4...  white
# 8   POLYGON ((-122.557048 47.40342099999999, -122....  white
# 48  POLYGON ((-122.497524 47.184709, -122.492754 4...  white
# 54  POLYGON ((-122.42168 47.067909, -122.432434 47...  white
# 34  POLYGON ((-122.145779 47.257408, -122.145551 4...  white
# 46  POLYGON ((-122.282407 47.193298, -122.282397 4...  white
# 33  POLYGON ((-122.127212 46.75394, -122.127302 46...  white
# 38  POLYGON ((-122.340429 47.641248, -122.343057 4...  green
# 50  POLYGON ((-122.29652 47.733784, -122.295306 47...  green
# 37  POLYGON ((-122.322376 47.652929, -122.322345 4...  green
# 49  POLYGON ((-122.24578 47.569033, -122.244154 47...  green
# 36  POLYGON ((-122.32246 47.59582899999999, -122.3...  green
# 39  POLYGON ((-122.253592 47.735662, -122.260836 4...  green
# 51  POLYGON ((-122.091933 47.653521, -122.096872 4...  green
# 53  POLYGON ((-122.153569 47.544563, -122.158432 4...  green
# 45  POLYGON ((-122.006097 47.637954, -122.005875 4...  green
# 52  POLYGON ((-122.183994 47.516732, -122.183606 4...    red
# 35  POLYGON ((-122.265408 47.489329, -122.265162 4...    red
# 9   POLYGON ((-122.335874 47.26382, -122.336765 47...    red
# 44  POLYGON ((-122.202416 47.344609, -122.202867 4...    red
# 42  POLYGON ((-122.219301 47.25745999999999, -122....    red
# 41  POLYGON ((-121.996029 47.280117, -121.99615 47...    red
# 32  POLYGON ((-121.87736 47.500683, -121.877455 47...  green
# 10  POLYGON ((-122.298118 47.777425, -122.298211 4...  white
# 11  POLYGON ((-122.238814 47.881905, -122.23806 47...  white
# 12  POLYGON ((-122.199839 47.878068, -122.200124 4...  white
# 40  POLYGON ((-122.14544 47.776142, -122.148026 47...  white
# 13  (POLYGON ((-122.322087 48.020457, -122.322013 ...  white
# 27  POLYGON ((-122.140305 48.297807, -122.140211 4...  white
# 26  POLYGON ((-122.52814 47.527728, -122.528627 47...  white
# 31  (POLYGON ((-122.509646 47.545959, -122.509171 ...  white
# 19  POLYGON ((-123.101738 48.317167, -123.09737 48...  white

# %% [markdown]
# This portion of code was used to create a separate dataframe of counties that are ony located within King county

# %%
new_df = wa_df[(wa_df['PUMACE10']>= 11601) & (wa_df['PUMACE10']<= 11616)]

# %%
new_df.head()
# Out:
#    STATEFP10  PUMACE10  GEOID10  \
# 9         53     11612  5311612
# 32        53     11616  5311616
# 35        53     11611  5311611
# 36        53     11605  5311605
# 37        53     11603  5311603
#
#                                            NAMELSAD10 MTFCC10 FUNCSTAT10  \
# 9   King County (Far Southwest)--Federal Way, Des ...   G6120          S
# 32  King County (Northeast)--Snoqualmie City, Cott...   G6120          S
# 35  King County (West Central)--Burien, SeaTac, Tu...   G6120          S
# 36   Seattle City (West)--Duwamish & Beacon Hill PUMA   G6120          S
# 37  Seattle City (Downtown)--Queen Anne & Magnolia...   G6120          S
#
#        ALAND10   AWATER10   INTPTLAT10    INTPTLON10  \
# 9    160638807  279665546  +47.4764651  -122.4271168
# 32  2477645989   49838932  +47.5779171  -121.6433869
# 35   104685305    6835973  +47.4500687  -122.3101564
# 36    70104140   10124676  +47.5521279  -122.3523950
# 37    29279826    8323991  +47.6391415  -122.3720415
#
#                                              geometry  color
# 9   POLYGON ((-122.335874 47.26382, -122.336765 47...    red
# 32  POLYGON ((-121.87736 47.500683, -121.877455 47...  green
# 35  POLYGON ((-122.265408 47.489329, -122.265162 4...    red
# 36  POLYGON ((-122.32246 47.59582899999999, -122.3...  green
# 37  POLYGON ((-122.322376 47.652929, -122.322345 4...  green

# %% [markdown]
# ## Plotting the Data

# %%
f, ax = plt.subplots(nrows = 1, ncols = 2, figsize = (15,6))

ax[0] = wa_df.plot(ax=ax[0], color = wa_df['color'], edgecolor = '#444444')
ax[0].set_axis_off()

ax[1] = new_df.plot(ax=ax[1], color = new_df['color'], edgecolor = '#444444')
ax[1].set_axis_off()

red_patch = mpatches.Patch(color='red', label='South King County')
green_patch = mpatches.Patch(color='green', label='North King County & Seattle')
blue_patch = mpatches.Patch(color='white', label='Outside King County')

ax[0].title.set_text("All of Washington")
ax[1].title.set_text("King County")

ax[0].legend(handles=[red_patch, green_patch, blue_patch], loc = 4, prop = {'size': 10}, edgecolor = '#444444', facecolor = '#bbbbbb')

# %% [markdown]
# ### Query for to create Heat map

# %%
import geoplot
import geopandas
from sqlalchemy import create_engine

# %%
engine = create_engine('postgresql:///opportunity_youth') # since database is owned by me, no other credentials are needed

# %%
geoplot.polyplot(wa_df, figsize = (8,4))

# %%
geoplot.choropleth(
    wa_df, hue=world['gdp_md_est'] / world['pop_est'],
    cmap='Greens', figsize=(8, 4)
)
